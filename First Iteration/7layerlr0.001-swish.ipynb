# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch.nn.functional as F
import matplotlib.pyplot as plt
import time


# Define the CNN model
# Define the CNN model using Swish
class CNNModel(nn.Module):
    def __init__(self, num_classes=65):  # Set num_classes to 65 
        super(CNNModel, self).__init__()
        self.num_classes = num_classes
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=1, padding=1)
        self.conv4 = nn.Conv2d(32, 64, kernel_size=3)
        self.conv5 = nn.Conv2d(64, 64, kernel_size=3)
        self.conv6 = nn.Conv2d(64, 128, kernel_size=5, stride=1, padding=1)
        self.conv7 = nn.Conv2d(128, 128, kernel_size=2)  # Reduced kernel size to 2x2
        self.batch_norm = nn.BatchNorm2d(128)
        self.dropout = nn.Dropout(0.5)

        # Calculate the input size for the fully connected layer dynamically
        self.fc1 = None
        self.swish = lambda x: x * torch.sigmoid(x)  # Define Swish activation function

    def forward(self, x):
        x = self.swish(self.conv1(x))
        x = self.swish(self.conv2(x))
        x = self.swish(self.conv3(x))
        x = self.dropout(x)
        x = self.swish(self.conv4(x))
        x = self.swish(self.conv5(x))
        x = self.swish(self.conv6(x))
        x = self.dropout(x)
        x = self.swish(self.conv7(x))
        x = self.batch_norm(x)

        # Flatten the tensor
        x = x.view(x.size(0), -1)

        # Dynamically define the fully connected layer based on the input size
        if self.fc1 is None:
            self.fc1 = nn.Linear(x.size(1), self.num_classes)
            self.fc1 = self.fc1.to(x.device)

        x = self.dropout(x)
        x = self.fc1(x)
        return F.log_softmax(x, dim=1)


# Data paths
train_data_dir = 'dataset'  # Update this with your dataset path
batch_size = 64
img_size = 28

# Define data transformations
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale
    transforms.Resize((img_size, img_size)),
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize((0.5,), (0.5,))  # Normalize
])

# Load the dataset
train_dataset = datasets.ImageFolder(train_data_dir, transform=transform)

# Split the data into train and validation
train_size = int(0.9 * len(train_dataset))
valid_size = len(train_dataset) - train_size
train_dataset, valid_dataset = torch.utils.data.random_split(train_dataset, [train_size, valid_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# Instantiate the model, loss function, and optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNModel(num_classes=65).to(device)  # 65 classes for Nepal Bhasa characters
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Lists to store loss and accuracy values
train_losses, valid_losses = [], []
train_accuracies, valid_accuracies = [], []

# Training loop
num_epochs = 200
start_time = time.time()
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        # Zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

        # Calculate accuracy
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)

    # Validation loop
    model.eval()
    valid_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in valid_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            valid_loss += loss.item()
            
            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    valid_loss = valid_loss / len(valid_loader)
    valid_acc = 100 * correct / total
    valid_losses.append(valid_loss)
    valid_accuracies.append(valid_acc)

    print(f"Epoch [{epoch+1}/{num_epochs}], "
          f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, "
          f"Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.2f}%")
# End timing
end_time = time.time()
training_time = (end_time - start_time)/60

print(f"Total training time: {training_time:.2f} minutes")
# Plot training and validation loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(valid_accuracies, label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.tight_layout()
plt.show()

# Save the model after training
torch.save(model.state_dict(), 'nepal_bhasa_cnn_newLR0.0001.pth')
# Out:
# C:\Users\HP\Desktop\Python\chatbot\Lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch [1/200], Train Loss: 4.0737, Train Accuracy: 5.67%, Validation Loss: 3.5599, Validation Accuracy: 17.54%
# Epoch [2/200], Train Loss: 3.7402, Train Accuracy: 12.06%, Validation Loss: 3.4038, Validation Accuracy: 19.15%
# Epoch [3/200], Train Loss: 3.5733, Train Accuracy: 15.27%, Validation Loss: 3.2188, Validation Accuracy: 20.91%
# Epoch [4/200], Train Loss: 3.4211, Train Accuracy: 18.64%, Validation Loss: 3.0341, Validation Accuracy: 25.15%
# Epoch [5/200], Train Loss: 3.2539, Train Accuracy: 22.29%, Validation Loss: 2.8611, Validation Accuracy: 30.70%
# Epoch [6/200], Train Loss: 3.0784, Train Accuracy: 26.55%, Validation Loss: 2.7394, Validation Accuracy: 34.50%
# Epoch [7/200], Train Loss: 2.8944, Train Accuracy: 31.25%, Validation Loss: 2.5822, Validation Accuracy: 40.35%
# Epoch [8/200], Train Loss: 2.7439, Train Accuracy: 34.77%, Validation Loss: 2.4659, Validation Accuracy: 43.86%
# Epoch [9/200], Train Loss: 2.6050, Train Accuracy: 38.63%, Validation Loss: 2.3581, Validation Accuracy: 48.83%
# Epoch [10/200], Train Loss: 2.4323, Train Accuracy: 42.35%, Validation Loss: 2.2135, Validation Accuracy: 49.42%
# Epoch [11/200], Train Loss: 2.3189, Train Accuracy: 45.32%, Validation Loss: 2.1194, Validation Accuracy: 51.90%
# Epoch [12/200], Train Loss: 2.1911, Train Accuracy: 48.49%, Validation Loss: 2.0092, Validation Accuracy: 52.78%
# Epoch [13/200], Train Loss: 2.0455, Train Accuracy: 52.23%, Validation Loss: 1.9064, Validation Accuracy: 55.26%
# Epoch [14/200], Train Loss: 1.9456, Train Accuracy: 53.85%, Validation Loss: 1.8654, Validation Accuracy: 59.36%
# Epoch [15/200], Train Loss: 1.8633, Train Accuracy: 56.00%, Validation Loss: 1.7214, Validation Accuracy: 62.87%
# Epoch [16/200], Train Loss: 1.7522, Train Accuracy: 58.97%, Validation Loss: 1.6738, Validation Accuracy: 62.13%
# Epoch [17/200], Train Loss: 1.6412, Train Accuracy: 60.76%, Validation Loss: 1.6069, Validation Accuracy: 62.72%
# Epoch [18/200], Train Loss: 1.5662, Train Accuracy: 63.02%, Validation Loss: 1.5484, Validation Accuracy: 62.87%
# Epoch [19/200], Train Loss: 1.5105, Train Accuracy: 63.86%, Validation Loss: 1.5133, Validation Accuracy: 64.62%
# Epoch [20/200], Train Loss: 1.4283, Train Accuracy: 65.05%, Validation Loss: 1.4441, Validation Accuracy: 66.67%
# Epoch [21/200], Train Loss: 1.3339, Train Accuracy: 67.58%, Validation Loss: 1.4281, Validation Accuracy: 68.13%
# Epoch [22/200], Train Loss: 1.3175, Train Accuracy: 68.67%, Validation Loss: 1.3871, Validation Accuracy: 68.57%
# Epoch [23/200], Train Loss: 1.2470, Train Accuracy: 69.73%, Validation Loss: 1.3481, Validation Accuracy: 69.59%
# Epoch [24/200], Train Loss: 1.1847, Train Accuracy: 71.79%, Validation Loss: 1.3444, Validation Accuracy: 68.86%
# Epoch [25/200], Train Loss: 1.1393, Train Accuracy: 72.21%, Validation Loss: 1.2766, Validation Accuracy: 69.44%
# Epoch [26/200], Train Loss: 1.0804, Train Accuracy: 74.16%, Validation Loss: 1.2801, Validation Accuracy: 68.42%
# Epoch [27/200], Train Loss: 1.0581, Train Accuracy: 74.72%, Validation Loss: 1.2543, Validation Accuracy: 71.64%
# Epoch [28/200], Train Loss: 1.0198, Train Accuracy: 75.12%, Validation Loss: 1.2017, Validation Accuracy: 71.78%
# Epoch [29/200], Train Loss: 0.9718, Train Accuracy: 76.36%, Validation Loss: 1.2096, Validation Accuracy: 71.05%
# Epoch [30/200], Train Loss: 0.9282, Train Accuracy: 76.96%, Validation Loss: 1.2028, Validation Accuracy: 71.49%
# Epoch [31/200], Train Loss: 0.8917, Train Accuracy: 78.06%, Validation Loss: 1.1960, Validation Accuracy: 71.78%
# Epoch [32/200], Train Loss: 0.8677, Train Accuracy: 78.05%, Validation Loss: 1.1954, Validation Accuracy: 71.93%
# Epoch [33/200], Train Loss: 0.8169, Train Accuracy: 80.31%, Validation Loss: 1.1330, Validation Accuracy: 73.68%
# Epoch [34/200], Train Loss: 0.8135, Train Accuracy: 79.85%, Validation Loss: 1.1426, Validation Accuracy: 73.39%
# Epoch [35/200], Train Loss: 0.7907, Train Accuracy: 80.81%, Validation Loss: 1.1495, Validation Accuracy: 74.12%
# Epoch [36/200], Train Loss: 0.7805, Train Accuracy: 80.45%, Validation Loss: 1.1451, Validation Accuracy: 74.71%
# Epoch [37/200], Train Loss: 0.7337, Train Accuracy: 81.33%, Validation Loss: 1.1076, Validation Accuracy: 74.27%
# Epoch [38/200], Train Loss: 0.7072, Train Accuracy: 82.16%, Validation Loss: 1.1255, Validation Accuracy: 73.98%
# Epoch [39/200], Train Loss: 0.7056, Train Accuracy: 81.87%, Validation Loss: 1.1233, Validation Accuracy: 73.68%
# Epoch [40/200], Train Loss: 0.6973, Train Accuracy: 81.91%, Validation Loss: 1.1062, Validation Accuracy: 73.68%
# Epoch [41/200], Train Loss: 0.6533, Train Accuracy: 83.80%, Validation Loss: 1.0904, Validation Accuracy: 73.54%
# Epoch [42/200], Train Loss: 0.6108, Train Accuracy: 84.64%, Validation Loss: 1.0756, Validation Accuracy: 74.12%
# Epoch [43/200], Train Loss: 0.6209, Train Accuracy: 84.04%, Validation Loss: 1.0852, Validation Accuracy: 74.42%
# Epoch [44/200], Train Loss: 0.6153, Train Accuracy: 84.17%, Validation Loss: 1.0447, Validation Accuracy: 75.15%
# Epoch [45/200], Train Loss: 0.5773, Train Accuracy: 85.00%, Validation Loss: 1.0578, Validation Accuracy: 74.56%
# Epoch [46/200], Train Loss: 0.5906, Train Accuracy: 85.29%, Validation Loss: 1.0533, Validation Accuracy: 74.85%
# Epoch [47/200], Train Loss: 0.5569, Train Accuracy: 85.68%, Validation Loss: 1.0767, Validation Accuracy: 73.54%
# Epoch [48/200], Train Loss: 0.5284, Train Accuracy: 86.66%, Validation Loss: 1.0994, Validation Accuracy: 72.95%
# Epoch [49/200], Train Loss: 0.5298, Train Accuracy: 86.25%, Validation Loss: 1.0549, Validation Accuracy: 75.00%
# Epoch [50/200], Train Loss: 0.5227, Train Accuracy: 86.35%, Validation Loss: 1.0469, Validation Accuracy: 75.29%
# Epoch [51/200], Train Loss: 0.5197, Train Accuracy: 86.63%, Validation Loss: 1.0674, Validation Accuracy: 73.83%
# Epoch [52/200], Train Loss: 0.5275, Train Accuracy: 86.25%, Validation Loss: 1.0290, Validation Accuracy: 76.32%
# Epoch [53/200], Train Loss: 0.5127, Train Accuracy: 86.46%, Validation Loss: 1.0479, Validation Accuracy: 75.00%
# Epoch [54/200], Train Loss: 0.4740, Train Accuracy: 87.83%, Validation Loss: 1.0196, Validation Accuracy: 75.15%
# Epoch [55/200], Train Loss: 0.4803, Train Accuracy: 87.52%, Validation Loss: 1.0408, Validation Accuracy: 75.88%
# Epoch [56/200], Train Loss: 0.4672, Train Accuracy: 87.62%, Validation Loss: 1.0162, Validation Accuracy: 74.42%
# Epoch [57/200], Train Loss: 0.4517, Train Accuracy: 87.93%, Validation Loss: 1.0273, Validation Accuracy: 75.29%
# Epoch [58/200], Train Loss: 0.4462, Train Accuracy: 88.27%, Validation Loss: 1.0214, Validation Accuracy: 75.29%
# Epoch [59/200], Train Loss: 0.4305, Train Accuracy: 88.48%, Validation Loss: 1.0690, Validation Accuracy: 74.42%
# Epoch [60/200], Train Loss: 0.4387, Train Accuracy: 88.32%, Validation Loss: 1.0613, Validation Accuracy: 74.56%
# Epoch [61/200], Train Loss: 0.4444, Train Accuracy: 88.33%, Validation Loss: 1.0443, Validation Accuracy: 74.12%
# Epoch [62/200], Train Loss: 0.4131, Train Accuracy: 89.29%, Validation Loss: 1.0301, Validation Accuracy: 75.29%
# Epoch [63/200], Train Loss: 0.4435, Train Accuracy: 88.35%, Validation Loss: 1.0646, Validation Accuracy: 73.98%
# Epoch [64/200], Train Loss: 0.4110, Train Accuracy: 88.89%, Validation Loss: 1.0589, Validation Accuracy: 74.71%
# Epoch [65/200], Train Loss: 0.3945, Train Accuracy: 89.16%, Validation Loss: 1.0837, Validation Accuracy: 73.25%
# Epoch [66/200], Train Loss: 0.3915, Train Accuracy: 89.26%, Validation Loss: 1.0572, Validation Accuracy: 74.85%
# Epoch [67/200], Train Loss: 0.3840, Train Accuracy: 89.34%, Validation Loss: 1.0259, Validation Accuracy: 75.15%
# Epoch [68/200], Train Loss: 0.3906, Train Accuracy: 89.15%, Validation Loss: 1.0706, Validation Accuracy: 74.27%
# Epoch [69/200], Train Loss: 0.3678, Train Accuracy: 90.12%, Validation Loss: 1.0555, Validation Accuracy: 76.46%
# Epoch [70/200], Train Loss: 0.3737, Train Accuracy: 89.45%, Validation Loss: 1.0651, Validation Accuracy: 74.56%
# Epoch [71/200], Train Loss: 0.3825, Train Accuracy: 89.50%, Validation Loss: 1.0890, Validation Accuracy: 73.83%
# Epoch [72/200], Train Loss: 0.3696, Train Accuracy: 89.44%, Validation Loss: 1.1327, Validation Accuracy: 74.42%
# Epoch [73/200], Train Loss: 0.3615, Train Accuracy: 89.97%, Validation Loss: 1.1129, Validation Accuracy: 74.42%
# Epoch [74/200], Train Loss: 0.3522, Train Accuracy: 90.58%, Validation Loss: 1.0944, Validation Accuracy: 74.71%
# Epoch [75/200], Train Loss: 0.3533, Train Accuracy: 90.27%, Validation Loss: 1.0601, Validation Accuracy: 74.85%
# Epoch [76/200], Train Loss: 0.3479, Train Accuracy: 90.15%, Validation Loss: 1.0436, Validation Accuracy: 75.00%
# Epoch [77/200], Train Loss: 0.3539, Train Accuracy: 90.09%, Validation Loss: 1.0688, Validation Accuracy: 74.42%
# Epoch [78/200], Train Loss: 0.3728, Train Accuracy: 89.68%, Validation Loss: 1.0224, Validation Accuracy: 74.85%
# Epoch [79/200], Train Loss: 0.3378, Train Accuracy: 90.20%, Validation Loss: 1.0276, Validation Accuracy: 75.29%
# Epoch [80/200], Train Loss: 0.3512, Train Accuracy: 90.27%, Validation Loss: 1.0521, Validation Accuracy: 75.73%
# Epoch [81/200], Train Loss: 0.3267, Train Accuracy: 91.19%, Validation Loss: 1.0862, Validation Accuracy: 74.56%
# Epoch [82/200], Train Loss: 0.3397, Train Accuracy: 90.59%, Validation Loss: 1.0530, Validation Accuracy: 75.73%
# Epoch [83/200], Train Loss: 0.3348, Train Accuracy: 90.54%, Validation Loss: 1.0696, Validation Accuracy: 75.29%
# Epoch [84/200], Train Loss: 0.3379, Train Accuracy: 90.43%, Validation Loss: 1.0962, Validation Accuracy: 75.00%
# Epoch [85/200], Train Loss: 0.3578, Train Accuracy: 89.91%, Validation Loss: 1.0933, Validation Accuracy: 74.27%
# Epoch [86/200], Train Loss: 0.3273, Train Accuracy: 91.16%, Validation Loss: 1.0913, Validation Accuracy: 75.00%
# Epoch [87/200], Train Loss: 0.3398, Train Accuracy: 90.23%, Validation Loss: 1.0770, Validation Accuracy: 74.27%
# Epoch [88/200], Train Loss: 0.3315, Train Accuracy: 90.69%, Validation Loss: 1.1135, Validation Accuracy: 74.56%
# Epoch [89/200], Train Loss: 0.3311, Train Accuracy: 90.87%, Validation Loss: 1.1082, Validation Accuracy: 73.39%
# Epoch [90/200], Train Loss: 0.3270, Train Accuracy: 90.88%, Validation Loss: 1.0601, Validation Accuracy: 73.54%
# Epoch [91/200], Train Loss: 0.3313, Train Accuracy: 90.41%, Validation Loss: 1.0650, Validation Accuracy: 74.27%
# Epoch [92/200], Train Loss: 0.3287, Train Accuracy: 90.87%, Validation Loss: 1.0735, Validation Accuracy: 74.71%
# Epoch [93/200], Train Loss: 0.3125, Train Accuracy: 91.34%, Validation Loss: 1.1259, Validation Accuracy: 73.83%
# Epoch [94/200], Train Loss: 0.3171, Train Accuracy: 91.37%, Validation Loss: 1.0567, Validation Accuracy: 74.27%
# Epoch [95/200], Train Loss: 0.3088, Train Accuracy: 91.44%, Validation Loss: 1.0485, Validation Accuracy: 74.42%
# Epoch [96/200], Train Loss: 0.2967, Train Accuracy: 91.65%, Validation Loss: 1.0914, Validation Accuracy: 75.44%
# Epoch [97/200], Train Loss: 0.2987, Train Accuracy: 91.57%, Validation Loss: 1.1143, Validation Accuracy: 74.85%
# Epoch [98/200], Train Loss: 0.3015, Train Accuracy: 91.34%, Validation Loss: 1.0650, Validation Accuracy: 75.73%
# Epoch [99/200], Train Loss: 0.3075, Train Accuracy: 91.26%, Validation Loss: 1.1119, Validation Accuracy: 74.85%
# Epoch [100/200], Train Loss: 0.3077, Train Accuracy: 90.71%, Validation Loss: 1.0761, Validation Accuracy: 75.15%
# Epoch [101/200], Train Loss: 0.3075, Train Accuracy: 91.44%, Validation Loss: 1.1269, Validation Accuracy: 75.15%
# Epoch [102/200], Train Loss: 0.3099, Train Accuracy: 90.98%, Validation Loss: 1.0944, Validation Accuracy: 74.71%
# Epoch [103/200], Train Loss: 0.2872, Train Accuracy: 91.92%, Validation Loss: 1.0944, Validation Accuracy: 74.56%
# Epoch [104/200], Train Loss: 0.2915, Train Accuracy: 91.91%, Validation Loss: 1.0692, Validation Accuracy: 74.85%
# Epoch [105/200], Train Loss: 0.2969, Train Accuracy: 91.50%, Validation Loss: 1.0651, Validation Accuracy: 74.71%
# Epoch [106/200], Train Loss: 0.2865, Train Accuracy: 92.12%, Validation Loss: 1.0382, Validation Accuracy: 75.29%
# Epoch [107/200], Train Loss: 0.2773, Train Accuracy: 92.51%, Validation Loss: 1.0494, Validation Accuracy: 75.44%
# Epoch [108/200], Train Loss: 0.2903, Train Accuracy: 91.45%, Validation Loss: 1.0581, Validation Accuracy: 73.98%
# Epoch [109/200], Train Loss: 0.2829, Train Accuracy: 91.45%, Validation Loss: 1.0691, Validation Accuracy: 74.42%
# Epoch [110/200], Train Loss: 0.2530, Train Accuracy: 92.79%, Validation Loss: 1.0350, Validation Accuracy: 73.68%
# Epoch [111/200], Train Loss: 0.2623, Train Accuracy: 92.59%, Validation Loss: 1.0917, Validation Accuracy: 72.95%
# Epoch [112/200], Train Loss: 0.2881, Train Accuracy: 91.50%, Validation Loss: 1.0974, Validation Accuracy: 73.98%
# Epoch [113/200], Train Loss: 0.3065, Train Accuracy: 90.98%, Validation Loss: 1.0521, Validation Accuracy: 74.56%
# Epoch [114/200], Train Loss: 0.2486, Train Accuracy: 92.79%, Validation Loss: 1.0960, Validation Accuracy: 75.00%
# Epoch [115/200], Train Loss: 0.2817, Train Accuracy: 91.84%, Validation Loss: 1.0702, Validation Accuracy: 75.00%
# Epoch [116/200], Train Loss: 0.3174, Train Accuracy: 90.58%, Validation Loss: 1.0519, Validation Accuracy: 76.17%
# Epoch [117/200], Train Loss: 0.2770, Train Accuracy: 92.15%, Validation Loss: 1.0750, Validation Accuracy: 75.29%
# Epoch [118/200], Train Loss: 0.2628, Train Accuracy: 92.23%, Validation Loss: 1.0561, Validation Accuracy: 75.58%
# Epoch [119/200], Train Loss: 0.2853, Train Accuracy: 91.79%, Validation Loss: 1.0667, Validation Accuracy: 75.58%
# Epoch [120/200], Train Loss: 0.2792, Train Accuracy: 91.24%, Validation Loss: 1.0716, Validation Accuracy: 75.44%
# Epoch [121/200], Train Loss: 0.2618, Train Accuracy: 92.62%, Validation Loss: 1.1086, Validation Accuracy: 74.56%
# Epoch [122/200], Train Loss: 0.2505, Train Accuracy: 93.00%, Validation Loss: 1.0440, Validation Accuracy: 75.15%
# Epoch [123/200], Train Loss: 0.2603, Train Accuracy: 92.48%, Validation Loss: 1.0775, Validation Accuracy: 74.12%
# Epoch [124/200], Train Loss: 0.2756, Train Accuracy: 92.04%, Validation Loss: 1.0603, Validation Accuracy: 73.39%
# Epoch [125/200], Train Loss: 0.2657, Train Accuracy: 92.38%, Validation Loss: 1.0439, Validation Accuracy: 75.88%
# Epoch [126/200], Train Loss: 0.2484, Train Accuracy: 92.72%, Validation Loss: 1.0748, Validation Accuracy: 73.39%
# Epoch [127/200], Train Loss: 0.2691, Train Accuracy: 92.14%, Validation Loss: 1.0801, Validation Accuracy: 73.83%
# Epoch [128/200], Train Loss: 0.2571, Train Accuracy: 92.56%, Validation Loss: 1.1014, Validation Accuracy: 74.42%
# Epoch [129/200], Train Loss: 0.2584, Train Accuracy: 92.43%, Validation Loss: 1.0892, Validation Accuracy: 74.71%
# Epoch [130/200], Train Loss: 0.2526, Train Accuracy: 92.53%, Validation Loss: 1.0868, Validation Accuracy: 75.00%
# Epoch [131/200], Train Loss: 0.2658, Train Accuracy: 92.48%, Validation Loss: 1.1062, Validation Accuracy: 74.42%
# Epoch [132/200], Train Loss: 0.2664, Train Accuracy: 92.15%, Validation Loss: 1.0922, Validation Accuracy: 73.83%
# Epoch [133/200], Train Loss: 0.2430, Train Accuracy: 92.80%, Validation Loss: 1.0982, Validation Accuracy: 74.27%
# Epoch [134/200], Train Loss: 0.2441, Train Accuracy: 92.85%, Validation Loss: 1.1045, Validation Accuracy: 75.73%
# Epoch [135/200], Train Loss: 0.2588, Train Accuracy: 92.98%, Validation Loss: 1.1114, Validation Accuracy: 74.85%
# Epoch [136/200], Train Loss: 0.2661, Train Accuracy: 92.09%, Validation Loss: 1.1121, Validation Accuracy: 74.42%
# Epoch [137/200], Train Loss: 0.2865, Train Accuracy: 91.50%, Validation Loss: 1.0619, Validation Accuracy: 75.58%
# Epoch [138/200], Train Loss: 0.2784, Train Accuracy: 92.10%, Validation Loss: 1.0866, Validation Accuracy: 75.58%
# Epoch [139/200], Train Loss: 0.2489, Train Accuracy: 92.53%, Validation Loss: 1.1059, Validation Accuracy: 74.85%
# Epoch [140/200], Train Loss: 0.2287, Train Accuracy: 93.16%, Validation Loss: 1.1017, Validation Accuracy: 75.29%
# Epoch [141/200], Train Loss: 0.2143, Train Accuracy: 93.71%, Validation Loss: 1.1317, Validation Accuracy: 75.58%
# Epoch [142/200], Train Loss: 0.2317, Train Accuracy: 93.29%, Validation Loss: 1.0821, Validation Accuracy: 75.15%
# Epoch [143/200], Train Loss: 0.2314, Train Accuracy: 93.18%, Validation Loss: 1.1021, Validation Accuracy: 73.68%
# Epoch [144/200], Train Loss: 0.2545, Train Accuracy: 92.44%, Validation Loss: 1.0917, Validation Accuracy: 73.54%
# Epoch [145/200], Train Loss: 0.2320, Train Accuracy: 93.14%, Validation Loss: 1.0924, Validation Accuracy: 74.56%
# Epoch [146/200], Train Loss: 0.2405, Train Accuracy: 92.74%, Validation Loss: 1.0784, Validation Accuracy: 74.71%
# Epoch [147/200], Train Loss: 0.2489, Train Accuracy: 92.75%, Validation Loss: 1.1261, Validation Accuracy: 73.83%
# Epoch [148/200], Train Loss: 0.2273, Train Accuracy: 92.95%, Validation Loss: 1.1242, Validation Accuracy: 74.71%
# Epoch [149/200], Train Loss: 0.2355, Train Accuracy: 92.64%, Validation Loss: 1.0945, Validation Accuracy: 76.32%
# Epoch [150/200], Train Loss: 0.2338, Train Accuracy: 92.93%, Validation Loss: 1.0960, Validation Accuracy: 74.27%
# Epoch [151/200], Train Loss: 0.2329, Train Accuracy: 93.09%, Validation Loss: 1.0910, Validation Accuracy: 74.27%
# Epoch [152/200], Train Loss: 0.2485, Train Accuracy: 92.80%, Validation Loss: 1.1385, Validation Accuracy: 73.39%
# Epoch [153/200], Train Loss: 0.2432, Train Accuracy: 92.90%, Validation Loss: 1.0643, Validation Accuracy: 75.73%
# Epoch [154/200], Train Loss: 0.2534, Train Accuracy: 92.57%, Validation Loss: 1.1003, Validation Accuracy: 74.42%
# Epoch [155/200], Train Loss: 0.2446, Train Accuracy: 92.46%, Validation Loss: 1.1277, Validation Accuracy: 73.98%
# Epoch [156/200], Train Loss: 0.2346, Train Accuracy: 93.03%, Validation Loss: 1.1523, Validation Accuracy: 73.68%
# Epoch [157/200], Train Loss: 0.2278, Train Accuracy: 93.26%, Validation Loss: 1.1204, Validation Accuracy: 74.27%
# Epoch [158/200], Train Loss: 0.2377, Train Accuracy: 93.03%, Validation Loss: 1.1289, Validation Accuracy: 74.12%
# Epoch [159/200], Train Loss: 0.2143, Train Accuracy: 93.74%, Validation Loss: 1.1159, Validation Accuracy: 74.71%
# Epoch [160/200], Train Loss: 0.2239, Train Accuracy: 93.27%, Validation Loss: 1.1070, Validation Accuracy: 74.56%
# Epoch [161/200], Train Loss: 0.2350, Train Accuracy: 93.00%, Validation Loss: 1.0883, Validation Accuracy: 74.42%
# Epoch [162/200], Train Loss: 0.2269, Train Accuracy: 93.21%, Validation Loss: 1.1034, Validation Accuracy: 74.85%
# Epoch [163/200], Train Loss: 0.2254, Train Accuracy: 93.57%, Validation Loss: 1.1517, Validation Accuracy: 74.27%
# Epoch [164/200], Train Loss: 0.2390, Train Accuracy: 92.75%, Validation Loss: 1.1644, Validation Accuracy: 73.25%
# Epoch [165/200], Train Loss: 0.2166, Train Accuracy: 93.53%, Validation Loss: 1.1755, Validation Accuracy: 73.98%
# Epoch [166/200], Train Loss: 0.2347, Train Accuracy: 92.77%, Validation Loss: 1.1968, Validation Accuracy: 75.15%
# Epoch [167/200], Train Loss: 0.2405, Train Accuracy: 92.87%, Validation Loss: 1.1527, Validation Accuracy: 74.85%
# Epoch [168/200], Train Loss: 0.2308, Train Accuracy: 92.72%, Validation Loss: 1.1529, Validation Accuracy: 74.27%
# Epoch [169/200], Train Loss: 0.2288, Train Accuracy: 93.01%, Validation Loss: 1.2488, Validation Accuracy: 73.39%
# Epoch [170/200], Train Loss: 0.2243, Train Accuracy: 93.32%, Validation Loss: 1.1746, Validation Accuracy: 73.98%
# Epoch [171/200], Train Loss: 0.2228, Train Accuracy: 93.26%, Validation Loss: 1.1984, Validation Accuracy: 73.98%
# Epoch [172/200], Train Loss: 0.2246, Train Accuracy: 93.61%, Validation Loss: 1.2112, Validation Accuracy: 73.83%
# Epoch [173/200], Train Loss: 0.2309, Train Accuracy: 92.87%, Validation Loss: 1.1984, Validation Accuracy: 73.25%
# Epoch [174/200], Train Loss: 0.2304, Train Accuracy: 93.06%, Validation Loss: 1.1704, Validation Accuracy: 73.98%
# Epoch [175/200], Train Loss: 0.2149, Train Accuracy: 93.66%, Validation Loss: 1.1547, Validation Accuracy: 74.27%
# Epoch [176/200], Train Loss: 0.2238, Train Accuracy: 93.01%, Validation Loss: 1.1717, Validation Accuracy: 73.98%
# Epoch [177/200], Train Loss: 0.2268, Train Accuracy: 93.44%, Validation Loss: 1.2051, Validation Accuracy: 72.51%
# Epoch [178/200], Train Loss: 0.2232, Train Accuracy: 93.71%, Validation Loss: 1.2029, Validation Accuracy: 72.37%
# Epoch [179/200], Train Loss: 0.2077, Train Accuracy: 93.81%, Validation Loss: 1.1940, Validation Accuracy: 73.54%
# Epoch [180/200], Train Loss: 0.2319, Train Accuracy: 93.45%, Validation Loss: 1.1734, Validation Accuracy: 73.39%
# Epoch [181/200], Train Loss: 0.2421, Train Accuracy: 93.08%, Validation Loss: 1.1924, Validation Accuracy: 73.83%
# Epoch [182/200], Train Loss: 0.2746, Train Accuracy: 91.86%, Validation Loss: 1.1794, Validation Accuracy: 73.98%
# Epoch [183/200], Train Loss: 0.2290, Train Accuracy: 92.56%, Validation Loss: 1.1648, Validation Accuracy: 73.83%
# Epoch [184/200], Train Loss: 0.2115, Train Accuracy: 93.71%, Validation Loss: 1.1521, Validation Accuracy: 75.15%
# Epoch [185/200], Train Loss: 0.2270, Train Accuracy: 93.21%, Validation Loss: 1.2092, Validation Accuracy: 74.12%
# Epoch [186/200], Train Loss: 0.2270, Train Accuracy: 93.01%, Validation Loss: 1.1381, Validation Accuracy: 74.56%
# Epoch [187/200], Train Loss: 0.2317, Train Accuracy: 92.98%, Validation Loss: 1.1387, Validation Accuracy: 74.42%
# Epoch [188/200], Train Loss: 0.2197, Train Accuracy: 93.29%, Validation Loss: 1.1591, Validation Accuracy: 74.42%
# Epoch [189/200], Train Loss: 0.2126, Train Accuracy: 93.48%, Validation Loss: 1.1782, Validation Accuracy: 73.98%
# Epoch [190/200], Train Loss: 0.1984, Train Accuracy: 94.33%, Validation Loss: 1.1960, Validation Accuracy: 74.12%
# Epoch [191/200], Train Loss: 0.2114, Train Accuracy: 93.61%, Validation Loss: 1.1977, Validation Accuracy: 73.54%
# Epoch [192/200], Train Loss: 0.2216, Train Accuracy: 93.34%, Validation Loss: 1.1705, Validation Accuracy: 75.00%
# Epoch [193/200], Train Loss: 0.2057, Train Accuracy: 93.40%, Validation Loss: 1.1792, Validation Accuracy: 74.71%
# Epoch [194/200], Train Loss: 0.2022, Train Accuracy: 93.84%, Validation Loss: 1.1682, Validation Accuracy: 73.54%
# Epoch [195/200], Train Loss: 0.1846, Train Accuracy: 94.33%, Validation Loss: 1.1667, Validation Accuracy: 74.27%
# Epoch [196/200], Train Loss: 0.1839, Train Accuracy: 94.56%, Validation Loss: 1.1651, Validation Accuracy: 74.27%
# Epoch [197/200], Train Loss: 0.1898, Train Accuracy: 94.36%, Validation Loss: 1.1676, Validation Accuracy: 74.71%
# Epoch [198/200], Train Loss: 0.2184, Train Accuracy: 93.87%, Validation Loss: 1.1596, Validation Accuracy: 74.56%
# Epoch [199/200], Train Loss: 0.2263, Train Accuracy: 93.14%, Validation Loss: 1.1724, Validation Accuracy: 74.27%
# Epoch [200/200], Train Loss: 0.2207, Train Accuracy: 93.22%, Validation Loss: 1.2059, Validation Accuracy: 72.95%
# Total training time: 39.27 minutes

# %%
torch.save(model.state_dict(), 'nepal_bhasa_cnn_SwishLR0.001.pth')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from PIL import Image
import tkinter as tk
from tkinter import filedialog

# CNN Model Definition (same as used during training)
class CNNModel(nn.Module):
    def __init__(self, num_classes=65):  # Set num_classes to 65 for Nepal Bhasa characters
        super(CNNModel, self).__init__()
        self.num_classes = num_classes
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=1, padding=1)
        self.conv4 = nn.Conv2d(32, 64, kernel_size=3)
        self.conv5 = nn.Conv2d(64, 64, kernel_size=3)
        self.conv6 = nn.Conv2d(64, 128, kernel_size=5, stride=1, padding=1)
        self.conv7 = nn.Conv2d(128, 128, kernel_size=2)  # Reduced kernel size to 2x2
        self.batch_norm = nn.BatchNorm2d(128)
        
        self.dropout = nn.Dropout(0.5)
        # Define the fully connected layer in the constructor
        self.fc1 = nn.Linear(128 * 15 * 15, self.num_classes)
        # self.fc1=None

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = self.dropout(x)
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = self.dropout(x)
        x = F.relu(self.conv7(x))
        x = self.batch_norm(x)

        # Flatten the tensor
        x = x.view(x.size(0), -1)

        # if self.fc1 is None:
        #     self.fc1 = nn.Linear(x.size(1), self.num_classes).to(x.device)

        x = self.dropout(x)
        x = self.fc1(x)
        return F.log_softmax(x, dim=1)

# Load the trained model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNModel(num_classes=65)
model.load_state_dict(torch.load('nepal_bhasa_cnn_newLR0.0001.pth', map_location=device))
model.eval()
model.to(device)

# Define the transform (same as used during training)
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Ensure grayscale
    transforms.Resize((28, 28)),  # Resize to the same size used during training
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize((0.5,), (0.5,))  # Normalize
])

# Function to make a prediction
def predict_image(image_path):
    # Load the image
    image = Image.open(image_path)
    
    # Apply the transformations
    image = transform(image).unsqueeze(0).to(device)  # Add batch dimension

    # Make prediction
    with torch.no_grad():
        output = model(image)
        predicted_class = torch.argmax(output, dim=1).item()

    return predicted_class

# Function to upload and predict image+
def upload_and_predict():
    # Open file dialog to select image
    root = tk.Tk()
    root.withdraw()  # Hide the main tkinter window
    image_path = filedialog.askopenfilename()  # Open file dialog
    if image_path:
        predicted_class = predict_image(image_path)
        print(f'Predicted Class: {predicted_class}')
    else:
        print("No image selected.")

# Run the image upload and prediction
upload_and_predict()
# Out:
# Predicted Class: 63

# %%
11:23
2:10
