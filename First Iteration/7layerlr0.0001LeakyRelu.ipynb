# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch.nn.functional as F
import matplotlib.pyplot as plt
import time


# Define the CNN model
# Define the CNN model using Leaky ReLU
class CNNModel(nn.Module):
    def __init__(self, num_classes=65):  # Set num_classes to 65 
        super(CNNModel, self).__init__()
        self.num_classes = num_classes
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=1, padding=1)
        self.conv4 = nn.Conv2d(32, 64, kernel_size=3)
        self.conv5 = nn.Conv2d(64, 64, kernel_size=3)
        self.conv6 = nn.Conv2d(64, 128, kernel_size=5, stride=1, padding=1)
        self.conv7 = nn.Conv2d(128, 128, kernel_size=2)  # Reduced kernel size to 2x2
        self.batch_norm = nn.BatchNorm2d(128)
        self.dropout = nn.Dropout(0.5)

        # Calculate the input size for the fully connected layer dynamically
        self.fc1 = None
        self.leaky_relu = nn.LeakyReLU(0.01)  # Define Leaky ReLU activation function

    def forward(self, x):
        x = self.leaky_relu(self.conv1(x))
        x = self.leaky_relu(self.conv2(x))
        x = self.leaky_relu(self.conv3(x))
        x = self.dropout(x)
        x = self.leaky_relu(self.conv4(x))
        x = self.leaky_relu(self.conv5(x))
        x = self.leaky_relu(self.conv6(x))
        x = self.dropout(x)
        x = self.leaky_relu(self.conv7(x))
        x = self.batch_norm(x)

        # Flatten the tensor
        x = x.view(x.size(0), -1)

        # Dynamically define the fully connected layer based on the input size
        if self.fc1 is None:
            self.fc1 = nn.Linear(x.size(1), self.num_classes)
            self.fc1 = self.fc1.to(x.device)

        x = self.dropout(x)
        x = self.fc1(x)
        return F.log_softmax(x, dim=1)

# Data paths
train_data_dir = 'dataset'  # Update this with your dataset path
batch_size = 64
img_size = 28

# Define data transformations
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale
    transforms.Resize((img_size, img_size)),
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize((0.5,), (0.5,))  # Normalize
])

# Load the dataset
train_dataset = datasets.ImageFolder(train_data_dir, transform=transform)

# Split the data into train and validation
train_size = int(0.9 * len(train_dataset))
valid_size = len(train_dataset) - train_size
train_dataset, valid_dataset = torch.utils.data.random_split(train_dataset, [train_size, valid_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# Instantiate the model, loss function, and optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNModel(num_classes=65).to(device)  # 65 classes for Nepal Bhasa characters
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Lists to store loss and accuracy values
train_losses, valid_losses = [], []
train_accuracies, valid_accuracies = [], []

# Training loop
num_epochs = 200
start_time = time.time()
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        # Zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

        # Calculate accuracy
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)

    # Validation loop
    model.eval()
    valid_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in valid_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            valid_loss += loss.item()
            
            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    valid_loss = valid_loss / len(valid_loader)
    valid_acc = 100 * correct / total
    valid_losses.append(valid_loss)
    valid_accuracies.append(valid_acc)

    print(f"Epoch [{epoch+1}/{num_epochs}], "
          f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, "
          f"Validation Loss: {valid_loss:.4f}, Validation Accuracy: {valid_acc:.2f}%")
# End timing
end_time = time.time()
training_time = (end_time - start_time)/60

print(f"Total training time: {training_time:.2f} minutes")
# Plot training and validation loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(valid_accuracies, label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.tight_layout()
plt.show()

# Save the model after training
torch.save(model.state_dict(), 'nepal_bhasa_cnn_newLR0.0001.pth')
# Out:
# C:\Users\HP\Desktop\Python\chatbot\Lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch [1/200], Train Loss: 4.2290, Train Accuracy: 2.65%, Validation Loss: 4.1055, Validation Accuracy: 4.09%
# Epoch [2/200], Train Loss: 4.0062, Train Accuracy: 6.65%, Validation Loss: 3.8769, Validation Accuracy: 9.80%
# Epoch [3/200], Train Loss: 3.8516, Train Accuracy: 10.09%, Validation Loss: 3.7588, Validation Accuracy: 13.74%
# Epoch [4/200], Train Loss: 3.6935, Train Accuracy: 12.04%, Validation Loss: 3.5687, Validation Accuracy: 16.37%
# Epoch [5/200], Train Loss: 3.5670, Train Accuracy: 14.88%, Validation Loss: 3.3927, Validation Accuracy: 18.71%
# Epoch [6/200], Train Loss: 3.4382, Train Accuracy: 18.07%, Validation Loss: 3.2977, Validation Accuracy: 20.91%
# Epoch [7/200], Train Loss: 3.3170, Train Accuracy: 21.30%, Validation Loss: 3.2488, Validation Accuracy: 22.81%
# Epoch [8/200], Train Loss: 3.2233, Train Accuracy: 22.96%, Validation Loss: 3.1307, Validation Accuracy: 27.49%
# Epoch [9/200], Train Loss: 3.1005, Train Accuracy: 26.31%, Validation Loss: 3.0148, Validation Accuracy: 31.73%
# Epoch [10/200], Train Loss: 2.9879, Train Accuracy: 28.44%, Validation Loss: 2.8272, Validation Accuracy: 33.63%
# Epoch [11/200], Train Loss: 2.8925, Train Accuracy: 30.92%, Validation Loss: 2.8029, Validation Accuracy: 34.36%
# Epoch [12/200], Train Loss: 2.8008, Train Accuracy: 33.05%, Validation Loss: 2.7411, Validation Accuracy: 40.20%
# Epoch [13/200], Train Loss: 2.7029, Train Accuracy: 35.42%, Validation Loss: 2.6150, Validation Accuracy: 39.91%
# Epoch [14/200], Train Loss: 2.6237, Train Accuracy: 37.41%, Validation Loss: 2.4878, Validation Accuracy: 44.30%
# Epoch [15/200], Train Loss: 2.5319, Train Accuracy: 39.15%, Validation Loss: 2.4456, Validation Accuracy: 45.47%
# Epoch [16/200], Train Loss: 2.4526, Train Accuracy: 41.23%, Validation Loss: 2.3698, Validation Accuracy: 45.76%
# Epoch [17/200], Train Loss: 2.3749, Train Accuracy: 42.18%, Validation Loss: 2.2935, Validation Accuracy: 49.12%
# Epoch [18/200], Train Loss: 2.3206, Train Accuracy: 43.81%, Validation Loss: 2.2332, Validation Accuracy: 49.27%
# Epoch [19/200], Train Loss: 2.2329, Train Accuracy: 46.08%, Validation Loss: 2.1289, Validation Accuracy: 50.88%
# Epoch [20/200], Train Loss: 2.1861, Train Accuracy: 47.09%, Validation Loss: 2.1071, Validation Accuracy: 52.92%
# Epoch [21/200], Train Loss: 2.1155, Train Accuracy: 48.75%, Validation Loss: 2.0697, Validation Accuracy: 52.19%
# Epoch [22/200], Train Loss: 2.0468, Train Accuracy: 50.05%, Validation Loss: 1.9749, Validation Accuracy: 55.85%
# Epoch [23/200], Train Loss: 1.9771, Train Accuracy: 51.77%, Validation Loss: 1.9528, Validation Accuracy: 57.02%
# Epoch [24/200], Train Loss: 1.9564, Train Accuracy: 51.98%, Validation Loss: 1.9494, Validation Accuracy: 55.70%
# Epoch [25/200], Train Loss: 1.8931, Train Accuracy: 53.25%, Validation Loss: 1.8636, Validation Accuracy: 58.04%
# Epoch [26/200], Train Loss: 1.8467, Train Accuracy: 54.58%, Validation Loss: 1.8169, Validation Accuracy: 58.48%
# Epoch [27/200], Train Loss: 1.7824, Train Accuracy: 55.39%, Validation Loss: 1.7792, Validation Accuracy: 59.50%
# Epoch [28/200], Train Loss: 1.7299, Train Accuracy: 56.60%, Validation Loss: 1.7544, Validation Accuracy: 58.33%
# Epoch [29/200], Train Loss: 1.7181, Train Accuracy: 57.02%, Validation Loss: 1.7189, Validation Accuracy: 59.50%
# Epoch [30/200], Train Loss: 1.6847, Train Accuracy: 57.93%, Validation Loss: 1.6711, Validation Accuracy: 60.23%
# Epoch [31/200], Train Loss: 1.6336, Train Accuracy: 59.08%, Validation Loss: 1.6733, Validation Accuracy: 60.23%
# Epoch [32/200], Train Loss: 1.6010, Train Accuracy: 59.85%, Validation Loss: 1.6221, Validation Accuracy: 62.87%
# Epoch [33/200], Train Loss: 1.5558, Train Accuracy: 60.11%, Validation Loss: 1.5959, Validation Accuracy: 62.28%
# Epoch [34/200], Train Loss: 1.5165, Train Accuracy: 61.60%, Validation Loss: 1.5485, Validation Accuracy: 63.01%
# Epoch [35/200], Train Loss: 1.5115, Train Accuracy: 62.04%, Validation Loss: 1.5719, Validation Accuracy: 62.87%
# Epoch [36/200], Train Loss: 1.4663, Train Accuracy: 62.48%, Validation Loss: 1.5354, Validation Accuracy: 63.60%
# Epoch [37/200], Train Loss: 1.4333, Train Accuracy: 63.24%, Validation Loss: 1.6062, Validation Accuracy: 61.26%
# Epoch [38/200], Train Loss: 1.4116, Train Accuracy: 64.33%, Validation Loss: 1.4680, Validation Accuracy: 64.18%
# Epoch [39/200], Train Loss: 1.3598, Train Accuracy: 65.55%, Validation Loss: 1.4580, Validation Accuracy: 66.08%
# Epoch [40/200], Train Loss: 1.3595, Train Accuracy: 65.21%, Validation Loss: 1.4469, Validation Accuracy: 64.04%
# Epoch [41/200], Train Loss: 1.3234, Train Accuracy: 65.92%, Validation Loss: 1.4431, Validation Accuracy: 65.20%
# Epoch [42/200], Train Loss: 1.3127, Train Accuracy: 67.31%, Validation Loss: 1.4099, Validation Accuracy: 63.89%
# Epoch [43/200], Train Loss: 1.2949, Train Accuracy: 66.77%, Validation Loss: 1.4090, Validation Accuracy: 65.64%
# Epoch [44/200], Train Loss: 1.2652, Train Accuracy: 67.18%, Validation Loss: 1.3848, Validation Accuracy: 66.37%
# Epoch [45/200], Train Loss: 1.2487, Train Accuracy: 67.01%, Validation Loss: 1.3713, Validation Accuracy: 67.25%
# Epoch [46/200], Train Loss: 1.2035, Train Accuracy: 68.74%, Validation Loss: 1.3795, Validation Accuracy: 66.37%
# Epoch [47/200], Train Loss: 1.1838, Train Accuracy: 69.29%, Validation Loss: 1.3253, Validation Accuracy: 66.37%
# Epoch [48/200], Train Loss: 1.1829, Train Accuracy: 69.22%, Validation Loss: 1.3429, Validation Accuracy: 67.11%
# Epoch [49/200], Train Loss: 1.1624, Train Accuracy: 69.66%, Validation Loss: 1.3154, Validation Accuracy: 67.40%
# Epoch [50/200], Train Loss: 1.1295, Train Accuracy: 70.25%, Validation Loss: 1.3182, Validation Accuracy: 67.69%
# Epoch [51/200], Train Loss: 1.1175, Train Accuracy: 70.99%, Validation Loss: 1.2931, Validation Accuracy: 68.42%
# Epoch [52/200], Train Loss: 1.1061, Train Accuracy: 70.90%, Validation Loss: 1.3021, Validation Accuracy: 68.27%
# Epoch [53/200], Train Loss: 1.0790, Train Accuracy: 71.60%, Validation Loss: 1.2872, Validation Accuracy: 67.84%
# Epoch [54/200], Train Loss: 1.0399, Train Accuracy: 72.52%, Validation Loss: 1.2868, Validation Accuracy: 68.57%
# Epoch [55/200], Train Loss: 1.0344, Train Accuracy: 72.59%, Validation Loss: 1.2625, Validation Accuracy: 68.86%
# Epoch [56/200], Train Loss: 1.0517, Train Accuracy: 72.44%, Validation Loss: 1.2529, Validation Accuracy: 68.27%
# Epoch [57/200], Train Loss: 1.0115, Train Accuracy: 72.78%, Validation Loss: 1.2455, Validation Accuracy: 70.32%
# Epoch [58/200], Train Loss: 1.0100, Train Accuracy: 72.77%, Validation Loss: 1.2781, Validation Accuracy: 68.57%
# Epoch [59/200], Train Loss: 0.9976, Train Accuracy: 73.50%, Validation Loss: 1.2269, Validation Accuracy: 69.74%
# Epoch [60/200], Train Loss: 0.9873, Train Accuracy: 73.33%, Validation Loss: 1.2713, Validation Accuracy: 68.27%
# Epoch [61/200], Train Loss: 0.9568, Train Accuracy: 74.47%, Validation Loss: 1.2412, Validation Accuracy: 68.71%
# Epoch [62/200], Train Loss: 0.9494, Train Accuracy: 73.68%, Validation Loss: 1.2176, Validation Accuracy: 69.88%
# Epoch [63/200], Train Loss: 0.9324, Train Accuracy: 75.15%, Validation Loss: 1.2308, Validation Accuracy: 68.86%
# Epoch [64/200], Train Loss: 0.9407, Train Accuracy: 74.80%, Validation Loss: 1.2107, Validation Accuracy: 69.88%
# Epoch [65/200], Train Loss: 0.9308, Train Accuracy: 75.14%, Validation Loss: 1.1793, Validation Accuracy: 71.35%
# Epoch [66/200], Train Loss: 0.9081, Train Accuracy: 75.51%, Validation Loss: 1.2095, Validation Accuracy: 71.20%
# Epoch [67/200], Train Loss: 0.8745, Train Accuracy: 76.18%, Validation Loss: 1.1635, Validation Accuracy: 72.37%
# Epoch [68/200], Train Loss: 0.8540, Train Accuracy: 76.55%, Validation Loss: 1.1815, Validation Accuracy: 70.18%
# Epoch [69/200], Train Loss: 0.8557, Train Accuracy: 76.57%, Validation Loss: 1.1775, Validation Accuracy: 71.64%
# Epoch [70/200], Train Loss: 0.8434, Train Accuracy: 76.88%, Validation Loss: 1.2005, Validation Accuracy: 70.03%
# Epoch [71/200], Train Loss: 0.8228, Train Accuracy: 77.49%, Validation Loss: 1.1874, Validation Accuracy: 70.03%
# Epoch [72/200], Train Loss: 0.8112, Train Accuracy: 77.77%, Validation Loss: 1.1822, Validation Accuracy: 71.49%
# Epoch [73/200], Train Loss: 0.8292, Train Accuracy: 77.53%, Validation Loss: 1.1831, Validation Accuracy: 70.47%
# Epoch [74/200], Train Loss: 0.8059, Train Accuracy: 78.00%, Validation Loss: 1.1594, Validation Accuracy: 70.76%
# Epoch [75/200], Train Loss: 0.7801, Train Accuracy: 78.19%, Validation Loss: 1.2225, Validation Accuracy: 69.30%
# Epoch [76/200], Train Loss: 0.7966, Train Accuracy: 78.62%, Validation Loss: 1.1489, Validation Accuracy: 72.22%
# Epoch [77/200], Train Loss: 0.7859, Train Accuracy: 78.57%, Validation Loss: 1.1910, Validation Accuracy: 71.78%
# Epoch [78/200], Train Loss: 0.7543, Train Accuracy: 78.75%, Validation Loss: 1.1979, Validation Accuracy: 71.78%
# Epoch [79/200], Train Loss: 0.7379, Train Accuracy: 79.75%, Validation Loss: 1.1820, Validation Accuracy: 71.64%
# Epoch [80/200], Train Loss: 0.7414, Train Accuracy: 79.33%, Validation Loss: 1.1505, Validation Accuracy: 73.83%
# Epoch [81/200], Train Loss: 0.7047, Train Accuracy: 80.42%, Validation Loss: 1.1531, Validation Accuracy: 72.66%
# Epoch [82/200], Train Loss: 0.7099, Train Accuracy: 80.27%, Validation Loss: 1.1772, Validation Accuracy: 72.08%
# Epoch [83/200], Train Loss: 0.7286, Train Accuracy: 79.82%, Validation Loss: 1.1932, Validation Accuracy: 71.93%
# Epoch [84/200], Train Loss: 0.7346, Train Accuracy: 79.57%, Validation Loss: 1.1775, Validation Accuracy: 71.35%
# Epoch [85/200], Train Loss: 0.7180, Train Accuracy: 79.46%, Validation Loss: 1.1918, Validation Accuracy: 71.05%
# Epoch [86/200], Train Loss: 0.6898, Train Accuracy: 80.44%, Validation Loss: 1.2183, Validation Accuracy: 70.47%
# Epoch [87/200], Train Loss: 0.6813, Train Accuracy: 80.79%, Validation Loss: 1.1610, Validation Accuracy: 70.91%
# Epoch [88/200], Train Loss: 0.6890, Train Accuracy: 80.78%, Validation Loss: 1.1861, Validation Accuracy: 72.51%
# Epoch [89/200], Train Loss: 0.6361, Train Accuracy: 82.37%, Validation Loss: 1.1918, Validation Accuracy: 71.64%
# Epoch [90/200], Train Loss: 0.6737, Train Accuracy: 81.15%, Validation Loss: 1.1884, Validation Accuracy: 73.39%
# Epoch [91/200], Train Loss: 0.6429, Train Accuracy: 82.21%, Validation Loss: 1.1778, Validation Accuracy: 72.22%
# Epoch [92/200], Train Loss: 0.6685, Train Accuracy: 81.09%, Validation Loss: 1.1828, Validation Accuracy: 73.25%
# Epoch [93/200], Train Loss: 0.6506, Train Accuracy: 81.80%, Validation Loss: 1.1328, Validation Accuracy: 73.25%
# Epoch [94/200], Train Loss: 0.6235, Train Accuracy: 82.26%, Validation Loss: 1.1524, Validation Accuracy: 71.93%
# Epoch [95/200], Train Loss: 0.6490, Train Accuracy: 81.91%, Validation Loss: 1.1360, Validation Accuracy: 73.10%
# Epoch [96/200], Train Loss: 0.6394, Train Accuracy: 81.85%, Validation Loss: 1.1588, Validation Accuracy: 72.66%
# Epoch [97/200], Train Loss: 0.6307, Train Accuracy: 81.85%, Validation Loss: 1.1570, Validation Accuracy: 71.93%
# Epoch [98/200], Train Loss: 0.6352, Train Accuracy: 82.42%, Validation Loss: 1.1397, Validation Accuracy: 73.39%
# Epoch [99/200], Train Loss: 0.6613, Train Accuracy: 81.54%, Validation Loss: 1.1247, Validation Accuracy: 73.68%
# Epoch [100/200], Train Loss: 0.6220, Train Accuracy: 81.95%, Validation Loss: 1.1536, Validation Accuracy: 72.08%
# Epoch [101/200], Train Loss: 0.5804, Train Accuracy: 83.47%, Validation Loss: 1.1657, Validation Accuracy: 72.37%
# Epoch [102/200], Train Loss: 0.6002, Train Accuracy: 81.87%, Validation Loss: 1.1675, Validation Accuracy: 72.51%
# Epoch [103/200], Train Loss: 0.5821, Train Accuracy: 83.07%, Validation Loss: 1.1740, Validation Accuracy: 73.54%
# Epoch [104/200], Train Loss: 0.5892, Train Accuracy: 83.34%, Validation Loss: 1.1352, Validation Accuracy: 73.54%
# Epoch [105/200], Train Loss: 0.5503, Train Accuracy: 84.21%, Validation Loss: 1.1528, Validation Accuracy: 72.51%
# Epoch [106/200], Train Loss: 0.5614, Train Accuracy: 83.72%, Validation Loss: 1.1724, Validation Accuracy: 73.25%
# Epoch [107/200], Train Loss: 0.5829, Train Accuracy: 83.33%, Validation Loss: 1.1412, Validation Accuracy: 73.25%
# Epoch [108/200], Train Loss: 0.5591, Train Accuracy: 83.73%, Validation Loss: 1.1779, Validation Accuracy: 71.78%
# Epoch [109/200], Train Loss: 0.5385, Train Accuracy: 84.76%, Validation Loss: 1.1492, Validation Accuracy: 72.95%
# Epoch [110/200], Train Loss: 0.5563, Train Accuracy: 84.25%, Validation Loss: 1.1411, Validation Accuracy: 73.54%
# Epoch [111/200], Train Loss: 0.5523, Train Accuracy: 84.08%, Validation Loss: 1.1579, Validation Accuracy: 72.08%
# Epoch [112/200], Train Loss: 0.5397, Train Accuracy: 84.34%, Validation Loss: 1.1749, Validation Accuracy: 72.51%
# Epoch [113/200], Train Loss: 0.5463, Train Accuracy: 84.47%, Validation Loss: 1.1397, Validation Accuracy: 72.37%
# Epoch [114/200], Train Loss: 0.5291, Train Accuracy: 84.66%, Validation Loss: 1.1765, Validation Accuracy: 71.49%
# Epoch [115/200], Train Loss: 0.5233, Train Accuracy: 84.81%, Validation Loss: 1.1477, Validation Accuracy: 73.54%
# Epoch [116/200], Train Loss: 0.5257, Train Accuracy: 84.37%, Validation Loss: 1.1503, Validation Accuracy: 72.51%
# Epoch [117/200], Train Loss: 0.5175, Train Accuracy: 84.95%, Validation Loss: 1.1119, Validation Accuracy: 73.83%
# Epoch [118/200], Train Loss: 0.5576, Train Accuracy: 84.06%, Validation Loss: 1.1481, Validation Accuracy: 72.81%
# Epoch [119/200], Train Loss: 0.5315, Train Accuracy: 84.64%, Validation Loss: 1.1300, Validation Accuracy: 73.83%
# Epoch [120/200], Train Loss: 0.5150, Train Accuracy: 85.03%, Validation Loss: 1.1272, Validation Accuracy: 73.54%
# Epoch [121/200], Train Loss: 0.5062, Train Accuracy: 85.00%, Validation Loss: 1.1646, Validation Accuracy: 73.68%
# Epoch [122/200], Train Loss: 0.4687, Train Accuracy: 86.24%, Validation Loss: 1.1469, Validation Accuracy: 72.81%
# Epoch [123/200], Train Loss: 0.5086, Train Accuracy: 84.99%, Validation Loss: 1.1362, Validation Accuracy: 72.37%
# Epoch [124/200], Train Loss: 0.4970, Train Accuracy: 85.91%, Validation Loss: 1.1343, Validation Accuracy: 73.54%
# Epoch [125/200], Train Loss: 0.5068, Train Accuracy: 85.36%, Validation Loss: 1.2168, Validation Accuracy: 72.95%
# Epoch [126/200], Train Loss: 0.4814, Train Accuracy: 85.96%, Validation Loss: 1.1563, Validation Accuracy: 72.95%
# Epoch [127/200], Train Loss: 0.4798, Train Accuracy: 86.07%, Validation Loss: 1.1355, Validation Accuracy: 73.39%
# Epoch [128/200], Train Loss: 0.4823, Train Accuracy: 85.54%, Validation Loss: 1.1623, Validation Accuracy: 73.39%
# Epoch [129/200], Train Loss: 0.4662, Train Accuracy: 86.27%, Validation Loss: 1.1588, Validation Accuracy: 71.93%
# Epoch [130/200], Train Loss: 0.4852, Train Accuracy: 85.65%, Validation Loss: 1.1463, Validation Accuracy: 73.25%
# Epoch [131/200], Train Loss: 0.4643, Train Accuracy: 86.68%, Validation Loss: 1.1499, Validation Accuracy: 73.68%
# Epoch [132/200], Train Loss: 0.4680, Train Accuracy: 86.40%, Validation Loss: 1.2118, Validation Accuracy: 72.22%
# Epoch [133/200], Train Loss: 0.5082, Train Accuracy: 85.88%, Validation Loss: 1.2209, Validation Accuracy: 71.93%
# Epoch [134/200], Train Loss: 0.5080, Train Accuracy: 85.44%, Validation Loss: 1.1901, Validation Accuracy: 72.66%
# Epoch [135/200], Train Loss: 0.4876, Train Accuracy: 85.70%, Validation Loss: 1.2150, Validation Accuracy: 73.39%
# Epoch [136/200], Train Loss: 0.4512, Train Accuracy: 86.66%, Validation Loss: 1.1816, Validation Accuracy: 73.25%
# Epoch [137/200], Train Loss: 0.4405, Train Accuracy: 87.21%, Validation Loss: 1.2267, Validation Accuracy: 72.08%
# Epoch [138/200], Train Loss: 0.4504, Train Accuracy: 86.58%, Validation Loss: 1.1938, Validation Accuracy: 73.10%
# Epoch [139/200], Train Loss: 0.4400, Train Accuracy: 86.79%, Validation Loss: 1.2090, Validation Accuracy: 72.37%
# Epoch [140/200], Train Loss: 0.4516, Train Accuracy: 86.27%, Validation Loss: 1.1751, Validation Accuracy: 73.98%
# Epoch [141/200], Train Loss: 0.4391, Train Accuracy: 87.31%, Validation Loss: 1.1878, Validation Accuracy: 72.08%
# Epoch [142/200], Train Loss: 0.4493, Train Accuracy: 86.84%, Validation Loss: 1.1862, Validation Accuracy: 72.66%
# Epoch [143/200], Train Loss: 0.4287, Train Accuracy: 87.75%, Validation Loss: 1.1973, Validation Accuracy: 71.35%
# Epoch [144/200], Train Loss: 0.4343, Train Accuracy: 87.33%, Validation Loss: 1.2804, Validation Accuracy: 71.35%
# Epoch [145/200], Train Loss: 0.4247, Train Accuracy: 87.73%, Validation Loss: 1.1918, Validation Accuracy: 72.37%
# Epoch [146/200], Train Loss: 0.4119, Train Accuracy: 87.94%, Validation Loss: 1.1784, Validation Accuracy: 73.39%
# Epoch [147/200], Train Loss: 0.4085, Train Accuracy: 87.44%, Validation Loss: 1.1718, Validation Accuracy: 71.78%
# Epoch [148/200], Train Loss: 0.4402, Train Accuracy: 86.81%, Validation Loss: 1.1638, Validation Accuracy: 72.22%
# Epoch [149/200], Train Loss: 0.4113, Train Accuracy: 87.72%, Validation Loss: 1.2039, Validation Accuracy: 72.66%
# Epoch [150/200], Train Loss: 0.4461, Train Accuracy: 87.16%, Validation Loss: 1.2001, Validation Accuracy: 72.08%
# Epoch [151/200], Train Loss: 0.4447, Train Accuracy: 86.53%, Validation Loss: 1.1741, Validation Accuracy: 72.37%
# Epoch [152/200], Train Loss: 0.4288, Train Accuracy: 87.68%, Validation Loss: 1.1637, Validation Accuracy: 73.68%
# Epoch [153/200], Train Loss: 0.4151, Train Accuracy: 88.14%, Validation Loss: 1.1731, Validation Accuracy: 73.98%
# Epoch [154/200], Train Loss: 0.4179, Train Accuracy: 87.36%, Validation Loss: 1.1693, Validation Accuracy: 73.68%
# Epoch [155/200], Train Loss: 0.3998, Train Accuracy: 88.20%, Validation Loss: 1.1615, Validation Accuracy: 73.39%
# Epoch [156/200], Train Loss: 0.3907, Train Accuracy: 88.07%, Validation Loss: 1.1775, Validation Accuracy: 72.95%
# Epoch [157/200], Train Loss: 0.3991, Train Accuracy: 88.20%, Validation Loss: 1.1413, Validation Accuracy: 74.12%
# Epoch [158/200], Train Loss: 0.3974, Train Accuracy: 88.01%, Validation Loss: 1.1711, Validation Accuracy: 72.81%
# Epoch [159/200], Train Loss: 0.4046, Train Accuracy: 88.27%, Validation Loss: 1.1971, Validation Accuracy: 72.81%
# Epoch [160/200], Train Loss: 0.3961, Train Accuracy: 87.93%, Validation Loss: 1.2044, Validation Accuracy: 72.81%
# Epoch [161/200], Train Loss: 0.3955, Train Accuracy: 88.33%, Validation Loss: 1.1865, Validation Accuracy: 73.54%
# Epoch [162/200], Train Loss: 0.3792, Train Accuracy: 88.77%, Validation Loss: 1.2040, Validation Accuracy: 72.51%
# Epoch [163/200], Train Loss: 0.3926, Train Accuracy: 88.15%, Validation Loss: 1.2571, Validation Accuracy: 71.64%
# Epoch [164/200], Train Loss: 0.4112, Train Accuracy: 87.62%, Validation Loss: 1.2036, Validation Accuracy: 73.54%
# Epoch [165/200], Train Loss: 0.3872, Train Accuracy: 88.19%, Validation Loss: 1.2165, Validation Accuracy: 73.10%
# Epoch [166/200], Train Loss: 0.3788, Train Accuracy: 88.33%, Validation Loss: 1.2051, Validation Accuracy: 72.51%
# Epoch [167/200], Train Loss: 0.3861, Train Accuracy: 88.25%, Validation Loss: 1.1559, Validation Accuracy: 73.10%
# Epoch [168/200], Train Loss: 0.3739, Train Accuracy: 89.00%, Validation Loss: 1.1844, Validation Accuracy: 72.51%
# Epoch [169/200], Train Loss: 0.3929, Train Accuracy: 88.48%, Validation Loss: 1.1982, Validation Accuracy: 73.39%
# Epoch [170/200], Train Loss: 0.3951, Train Accuracy: 88.19%, Validation Loss: 1.2078, Validation Accuracy: 73.54%
# Epoch [171/200], Train Loss: 0.3805, Train Accuracy: 88.98%, Validation Loss: 1.1959, Validation Accuracy: 72.81%
# Epoch [172/200], Train Loss: 0.3812, Train Accuracy: 88.77%, Validation Loss: 1.1844, Validation Accuracy: 73.68%
# Epoch [173/200], Train Loss: 0.3751, Train Accuracy: 89.00%, Validation Loss: 1.2063, Validation Accuracy: 73.39%
# Epoch [174/200], Train Loss: 0.4045, Train Accuracy: 87.60%, Validation Loss: 1.2144, Validation Accuracy: 72.95%
# Epoch [175/200], Train Loss: 0.3721, Train Accuracy: 89.03%, Validation Loss: 1.2192, Validation Accuracy: 73.25%
# Epoch [176/200], Train Loss: 0.3502, Train Accuracy: 89.88%, Validation Loss: 1.1821, Validation Accuracy: 74.12%
# Epoch [177/200], Train Loss: 0.3770, Train Accuracy: 88.95%, Validation Loss: 1.2241, Validation Accuracy: 74.12%
# Epoch [178/200], Train Loss: 0.3799, Train Accuracy: 88.97%, Validation Loss: 1.2331, Validation Accuracy: 72.51%
# Epoch [179/200], Train Loss: 0.3566, Train Accuracy: 89.39%, Validation Loss: 1.2335, Validation Accuracy: 73.39%
# Epoch [180/200], Train Loss: 0.3759, Train Accuracy: 88.76%, Validation Loss: 1.2199, Validation Accuracy: 73.98%
# Epoch [181/200], Train Loss: 0.3840, Train Accuracy: 88.09%, Validation Loss: 1.2342, Validation Accuracy: 72.66%
# Epoch [182/200], Train Loss: 0.3915, Train Accuracy: 88.51%, Validation Loss: 1.2468, Validation Accuracy: 72.22%
# Epoch [183/200], Train Loss: 0.3726, Train Accuracy: 88.74%, Validation Loss: 1.2070, Validation Accuracy: 74.42%
# Epoch [184/200], Train Loss: 0.3409, Train Accuracy: 89.76%, Validation Loss: 1.1948, Validation Accuracy: 74.42%
# Epoch [185/200], Train Loss: 0.3596, Train Accuracy: 89.36%, Validation Loss: 1.2262, Validation Accuracy: 72.81%
# Epoch [186/200], Train Loss: 0.3406, Train Accuracy: 90.06%, Validation Loss: 1.2056, Validation Accuracy: 72.95%
# Epoch [187/200], Train Loss: 0.3608, Train Accuracy: 89.06%, Validation Loss: 1.2354, Validation Accuracy: 72.81%
# Epoch [188/200], Train Loss: 0.3438, Train Accuracy: 89.83%, Validation Loss: 1.1681, Validation Accuracy: 74.12%
# Epoch [189/200], Train Loss: 0.3491, Train Accuracy: 89.37%, Validation Loss: 1.1489, Validation Accuracy: 74.71%
# Epoch [190/200], Train Loss: 0.3548, Train Accuracy: 89.50%, Validation Loss: 1.2300, Validation Accuracy: 73.98%
# Epoch [191/200], Train Loss: 0.3765, Train Accuracy: 88.40%, Validation Loss: 1.2097, Validation Accuracy: 73.98%
# Epoch [192/200], Train Loss: 0.3464, Train Accuracy: 89.71%, Validation Loss: 1.2377, Validation Accuracy: 72.95%
# Epoch [193/200], Train Loss: 0.3596, Train Accuracy: 88.92%, Validation Loss: 1.2250, Validation Accuracy: 73.83%
# Epoch [194/200], Train Loss: 0.3288, Train Accuracy: 90.15%, Validation Loss: 1.2156, Validation Accuracy: 73.25%
# Epoch [195/200], Train Loss: 0.3216, Train Accuracy: 90.45%, Validation Loss: 1.2244, Validation Accuracy: 73.10%
# Epoch [196/200], Train Loss: 0.3512, Train Accuracy: 89.65%, Validation Loss: 1.2406, Validation Accuracy: 74.27%
# Epoch [197/200], Train Loss: 0.3621, Train Accuracy: 88.98%, Validation Loss: 1.2725, Validation Accuracy: 73.25%
# Epoch [198/200], Train Loss: 0.3675, Train Accuracy: 89.19%, Validation Loss: 1.2693, Validation Accuracy: 73.83%
# Epoch [199/200], Train Loss: 0.3467, Train Accuracy: 89.60%, Validation Loss: 1.2518, Validation Accuracy: 73.54%
# Epoch [200/200], Train Loss: 0.3428, Train Accuracy: 89.84%, Validation Loss: 1.2109, Validation Accuracy: 73.83%
# Total training time: 38.12 minutes

# %%
torch.save(model.state_dict(), 'nepal_bhasa_cnn_LeakyReluLR0.001.pth')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from PIL import Image
import tkinter as tk
from tkinter import filedialog

# CNN Model Definition (same as used during training)
class CNNModel(nn.Module):
    def __init__(self, num_classes=65):  # Set num_classes to 65 for Nepal Bhasa characters
        super(CNNModel, self).__init__()
        self.num_classes = num_classes
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=1, padding=1)
        self.conv4 = nn.Conv2d(32, 64, kernel_size=3)
        self.conv5 = nn.Conv2d(64, 64, kernel_size=3)
        self.conv6 = nn.Conv2d(64, 128, kernel_size=5, stride=1, padding=1)
        self.conv7 = nn.Conv2d(128, 128, kernel_size=2)  # Reduced kernel size to 2x2
        self.batch_norm = nn.BatchNorm2d(128)
        
        self.dropout = nn.Dropout(0.5)
        # Define the fully connected layer in the constructor
        self.fc1 = nn.Linear(128 * 15 * 15, self.num_classes)
        # self.fc1=None

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = self.dropout(x)
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = self.dropout(x)
        x = F.relu(self.conv7(x))
        x = self.batch_norm(x)

        # Flatten the tensor
        x = x.view(x.size(0), -1)

        # if self.fc1 is None:
        #     self.fc1 = nn.Linear(x.size(1), self.num_classes).to(x.device)

        x = self.dropout(x)
        x = self.fc1(x)
        return F.log_softmax(x, dim=1)

# Load the trained model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNModel(num_classes=65)
model.load_state_dict(torch.load('nepal_bhasa_cnn_newLR0.0001.pth', map_location=device))
model.eval()
model.to(device)

# Define the transform (same as used during training)
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Ensure grayscale
    transforms.Resize((28, 28)),  # Resize to the same size used during training
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize((0.5,), (0.5,))  # Normalize
])

# Function to make a prediction
def predict_image(image_path):
    # Load the image
    image = Image.open(image_path)
    
    # Apply the transformations
    image = transform(image).unsqueeze(0).to(device)  # Add batch dimension

    # Make prediction
    with torch.no_grad():
        output = model(image)
        predicted_class = torch.argmax(output, dim=1).item()

    return predicted_class

# Function to upload and predict image+
def upload_and_predict():
    # Open file dialog to select image
    root = tk.Tk()
    root.withdraw()  # Hide the main tkinter window
    image_path = filedialog.askopenfilename()  # Open file dialog
    if image_path:
        predicted_class = predict_image(image_path)
        print(f'Predicted Class: {predicted_class}')
    else:
        print("No image selected.")

# Run the image upload and prediction
upload_and_predict()
# Out:
# Predicted Class: 63

# %%
11:23
2:10
